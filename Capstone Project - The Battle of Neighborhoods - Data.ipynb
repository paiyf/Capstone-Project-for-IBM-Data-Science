# %% [markdown]
# ##  Select a location for café shop opening in Taichung City, Taiwan
#
# ### Analyze current café shop distribution in Taichung and try to select a suitable location

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in c:\users\user\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\user\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in c:\users\user\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: branca in c:\users\user\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'CZTYNXU2GXW1EQJ3F0TVJILHCIHFUFALLZX22JUOLJHINLSE' # your Foursquare ID
CLIENT_SECRET = 'XXCDRT0AASH4HV1XGPJ2PPOERZSA1SPWGZJPJ030F1T4QY5V' # your Foursquare Secret
ACCESS_TOKEN = 'TSRSRFVBG3LQQC2S5PUH0L30AQRMTEMYIVMKCLDNDHJLGDSB' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: CZTYNXU2GXW1EQJ3F0TVJILHCIHFUFALLZX22JUOLJHINLSE
# CLIENT_SECRET:XXCDRT0AASH4HV1XGPJ2PPOERZSA1SPWGZJPJ030F1T4QY5V

# %%
#Location near my home
latitude=24.150915
longitude=120.647743

# %% [markdown]
# ### Searching cafe shop with radius 1500m around my home

# %%
search_query = 'cafe'
radius = 1500
print(search_query + ' .... OK!')
# Out:
# cafe .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6046c4fa58a5ba570812a172'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '54313de3498e6691665c4933',
#     'name': 'Second Floor Cafe 貳樓',
#     'location': {'lat': 24.150993,
#      'lng': 120.647525,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.150993,
#        'lng': 120.647525}],
#      'distance': 23,
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '5775d3fc498e9957ef1f30c7',
#     'name': 'Heynuts Cafe (好堅果)',
#     'location': {'address': '西區精誠六街15號',
#      'lat': 24.155191,
#      'lng': 120.656951,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.155191,
#        'lng': 120.656951}],
#      'distance': 1049,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['西區精誠六街15號', '臺中市,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '539a7d48498eb12d43b7af4d',
#     'name': '貳樓 Second Floor Cafe',
#     'location': {'address': '公益路二段172號',
#      'lat': 24.150892507589937,
#      'lng': 120.64752349974786,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.150892507589937,
#        'lng': 120.64752349974786}],
#      'distance': 22,
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['公益路二段172號', '臺中市', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '50d0ff90e4b003c5d21034b3',
#     'name': '咖啡廳 Café Laurel',
#     'location': {'address': '台灣大道二段666號',
#      'lat': 24.159010174681473,
#      'lng': 120.65728425979613,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.159010174681473,
#        'lng': 120.65728425979613}],
#      'distance': 1323,
#      'postalCode': '407',
#      'cc': 'TW',
#      'city': '西屯',
#      'country': '臺灣',
#      'formattedAddress': ['台灣大道二段666號', '西屯,  407', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '57f9adad498e105e6c853d14',
#     'name': 'Café & Meal Muji (新光三越台中中港店)',
#     'location': {'address': '台灣大道301號11樓',
#      'lat': 24.165308,
#      'lng': 120.64415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.165308,
#        'lng': 120.64415}],
#      'distance': 1643,
#      'postalCode': '407',
#      'cc': 'TW',
#      'city': '西屯',
#      'country': '臺灣',
#      'formattedAddress': ['台灣大道301號11樓', '西屯,  407', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '547f36f5498e3f39b3094408',
#     'name': 'Cafe CoroCoro (Cafe CoroCoro カフェ コロコロ)',
#     'location': {'address': '華美西街一段81號',
#      'lat': 24.154793,
#      'lng': 120.659122,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.154793,
#        'lng': 120.659122}],
#      'distance': 1233,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '西區',
#      'country': '臺灣',
#      'formattedAddress': ['華美西街一段81號', '西區,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4e33c209227111ae76921a65',
#     'name': 'J-Ping Café',
#     'location': {'address': '文心路二段213號2樓',
#      'lat': 24.159968569507406,
#      'lng': 120.64777064064934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.159968569507406,
#        'lng': 120.64777064064934}],
#      'distance': 1007,
#      'cc': 'TW',
#      'city': '西屯',
#      'country': '臺灣',
#      'formattedAddress': ['文心路二段213號2樓', '西屯', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '524a8385498ebdced716f505',
#     'name': '這裡有猫cafe',
#     'location': {'lat': 24.145028606225782,
#      'lng': 120.65648766361457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.145028606225782,
#        'lng': 120.65648766361457}],
#      'distance': 1103,
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4bad7f67f964a520a6563be3',
#     'name': 'Cafe Terry',
#     'location': {'address': '418 Daying St.',
#      'crossStreet': 'DaDunShi',
#      'lat': 24.151553974069667,
#      'lng': 120.64870788234435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.151553974069667,
#        'lng': 120.64870788234435}],
#      'distance': 121,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '南屯區',
#      'country': '臺灣',
#      'formattedAddress': ['418 Daying St. (DaDunShi)', '南屯區,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4bce9248c564ef3b0d8eeef0',
#     'name': '呼嚕咖啡 Forro Cafe',
#     'location': {'address': '精誠三街47號',
#      'lat': 24.155802,
#      'lng': 120.65825,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.155802,
#        'lng': 120.65825}],
#      'distance': 1197,
#      'cc': 'TW',
#      'city': '西區',
#      'country': '臺灣',
#      'formattedAddress': ['精誠三街47號', '西區', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4e0e52e362e1d5a30d0063e6',
#     'name': '全壽Café',
#     'location': {'address': '館前路57號全國大飯店2樓',
#      'lat': 24.15371823354657,
#      'lng': 120.66353048677992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.15371823354657,
#        'lng': 120.66353048677992}],
#      'distance': 1633,
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['館前路57號全國大飯店2樓', '臺中市', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '51049cb1e4b05cc1c2d16130',
#     'name': 'Random cafe',
#     'location': {'address': '台中市西區華美西街一段81號',
#      'lat': 24.151785407338092,
#      'lng': 120.66180632334678,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.151785407338092,
#        'lng': 120.66180632334678}],
#      'distance': 1431,
#      'postalCode': '403',
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['台中市西區華美西街一段81號', '403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '57b000ae498eb17ed197cb15',
#     'name': 'SUNSHINE Dessert & cafe',
#     'location': {'lat': 24.151889,
#      'lng': 120.662082,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.151889,
#        'lng': 120.662082}],
#      'distance': 1460,
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4d0086721fcef04d3e26cbb9',
#     'name': 'Moment Cafe (磨時間咖啡)',
#     'location': {'address': '美村路一段117巷5號',
#      'lat': 24.15219794545733,
#      'lng': 120.66221630572157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.15219794545733,
#        'lng': 120.66221630572157}],
#      'distance': 1477,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '西區',
#      'country': '臺灣',
#      'formattedAddress': ['美村路一段117巷5號', '西區,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4d68eafdfd7ea35d53699e4a',
#     'name': 'ALLO Design / Café',
#     'location': {'address': '39 Huamei St.',
#      'lat': 24.14197595118602,
#      'lng': 120.65878629684448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.14197595118602,
#        'lng': 120.65878629684448}],
#      'distance': 1499,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['39 Huamei St.', '臺中市,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '5ab4a94e12f0a910329528ed',
#     'name': 'Saladaeng Cafe',
#     'location': {'address': '中興街81號',
#      'lat': 24.147414,
#      'lng': 120.663051,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.147414,
#        'lng': 120.663051}],
#      'distance': 1603,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['中興街81號', '臺中市,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '5058598ee4b043667339c936',
#     'name': 'Movenpick Cafe (莫凡彼咖啡館)',
#     'location': {'address': '臺灣大道二段459號4樓',
#      'crossStreet': '台中廣三SOGO店',
#      'lat': 24.155634,
#      'lng': 120.661739,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.155634,
#        'lng': 120.661739}],
#      'distance': 1515,
#      'cc': 'TW',
#      'city': '西區',
#      'country': '臺灣',
#      'formattedAddress': ['臺灣大道二段459號4樓 (台中廣三SOGO店)', '西區', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4dc8e9ffd164033c57346d48',
#     'name': '尼克咖啡 Naked Cafe',
#     'location': {'address': 'No. 229, ZhōngXìng St, West District',
#      'lat': 24.151422719504616,
#      'lng': 120.66339184834995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.151422719504616,
#        'lng': 120.66339184834995}],
#      'distance': 1590,
#      'postalCode': '403',
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['No. 229, ZhōngXìng St, West District',
#       'West District,  403',
#       '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '56e28789498e7b8a5884b7e4',
#     'name': '碰憩咖啡館 Risu Cafe',
#     'location': {'address': '南屯區干城街240巷1弄20號',
#      'lat': 24.151825,
#      'lng': 120.631634,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.151825,
#        'lng': 120.631634}],
#      'distance': 1639,
#      'postalCode': '408',
#      'cc': 'TW',
#      'city': '台中市；Taichung',
#      'country': '臺灣',
#      'formattedAddress': ['南屯區干城街240巷1弄20號', '台中市；Taichung,  408', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4e6b21fec65b5bef28b28156',
#     'name': 'Dazzling Cafe Sky',
#     'location': {'address': '臺中市新光三越百貨中港店4F',
#      'lat': 24.16395890249486,
#      'lng': 120.64277442331658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.16395890249486,
#        'lng': 120.64277442331658}],
#      'distance': 1537,
#      'cc': 'TW',
#      'city': '西屯區',
#      'country': '臺灣',
#      'formattedAddress': ['臺中市新光三越百貨中港店4F', '西屯區', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4f1a6ecde4b0d9f8b848cacb',
#     'name': 'Indié Room café',
#     'location': {'address': '西區健行路1049號2F',
#      'lat': 24.155977,
#      'lng': 120.663167,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.155977,
#        'lng': 120.663167}],
#      'distance': 1664,
#      'postalCode': '40353',
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['西區健行路1049號2F', '40353', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '588dbef445005e3255109b73',
#     'name': 'Manni Café (很多咖啡)',
#     'location': {'address': '17 Duxing Rd',
#      'crossStreet': 'Zhonghua Rd',
#      'lat': 24.144614,
#      'lng': 120.662808,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.144614,
#        'lng': 120.662808}],
#      'distance': 1683,
#      'cc': 'TW',
#      'neighborhood': 'Central District',
#      'country': '臺灣',
#      'formattedAddress': ['17 Duxing Rd (Zhonghua Rd)',
#       'Taichung City',
#       '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4fee800ce4b02af6a200a94b',
#     'name': 'blackpages CAFÉ',
#     'location': {'lat': 24.148972762600128,
#      'lng': 120.66506929669465,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.148972762600128,
#        'lng': 120.66506929669465}],
#      'distance': 1773,
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4c3702fe2c8020a1ca338800',
#     'name': 'Ino Café',
#     'location': {'address': '中興街175號',
#      'lat': 24.149843557357528,
#      'lng': 120.6631643145991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.149843557357528,
#        'lng': 120.6631643145991}],
#      'distance': 1570,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '西區',
#      'country': '臺灣',
#      'formattedAddress': ['中興街175號', '西區,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '54097222498ea5d6d2bc2ec9',
#     'name': 'Cafe lulu 自家烘焙任性咖啡館',
#     'location': {'address': '大墩十街70號',
#      'lat': 24.147769,
#      'lng': 120.652333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.147769,
#        'lng': 120.652333}],
#      'distance': 583,
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['大墩十街70號', '臺中市', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4d13389640e65481c68a951a',
#     'name': 'Café Grazie',
#     'location': {'address': '台中市文心路一段521號1樓',
#      'lat': 24.15412892426088,
#      'lng': 120.64700113215409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.15412892426088,
#        'lng': 120.64700113215409}],
#      'distance': 365,
#      'postalCode': '408',
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['台中市文心路一段521號1樓', 'Nantun District,  408', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '4d0c4ec1257d6dcb9efe9467',
#     'name': 'Oriel Cafe',
#     'location': {'lat': 24.152171,
#      'lng': 120.649614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.152171,
#        'lng': 120.649614}],
#      'distance': 235,
#      'cc': 'TW',
#      'country': '臺灣',
#      'formattedAddress': ['臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '5473eb8d498e20ea4408df2b',
#     'name': 'Cama Cafe （精明店）',
#     'location': {'address': '精誠路74號',
#      'lat': 24.155674775173292,
#      'lng': 120.65626590958459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.155674775173292,
#        'lng': 120.65626590958459}],
#      'distance': 1014,
#      'postalCode': '403',
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['精誠路74號', '臺中市,  403', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '540939e4498ee479aab67be6',
#     'name': '小醋Cafe',
#     'location': {'address': '臺中市南屯區大聖街238號',
#      'lat': 24.152652740478516,
#      'lng': 120.650634765625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.152652740478516,
#        'lng': 120.650634765625}],
#      'distance': 351,
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['臺中市南屯區大聖街238號', '臺中市', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False},
#    {'id': '551cff75498e1c7ffe88f507',
#     'name': 'Cafe Muah',
#     'location': {'address': '大墩十七街35號',
#      'crossStreet': '大墩路',
#      'lat': 24.155312,
#      'lng': 120.650138,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 24.155312,
#        'lng': 120.650138}],
#      'distance': 546,
#      'cc': 'TW',
#      'city': '臺中市',
#      'country': '臺灣',
#      'formattedAddress': ['大墩十七街35號 (大墩路)', '臺中市', '臺灣']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1615250682',
#     'hasPerk': False}]}}

# %% [markdown]
# ### Get the data we need

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(10)
# Out:
# <ipython-input-11-b0ac8c61cd59>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                                    name  \
# 0  54313de3498e6691665c4933                    Second Floor Cafe 貳樓
# 1  5775d3fc498e9957ef1f30c7                      Heynuts Cafe (好堅果)
# 2  539a7d48498eb12d43b7af4d                    貳樓 Second Floor Cafe
# 3  50d0ff90e4b003c5d21034b3                         咖啡廳 Café Laurel
# 4  57f9adad498e105e6c853d14            Café & Meal Muji (新光三越台中中港店)
# 5  547f36f5498e3f39b3094408  Cafe CoroCoro (Cafe CoroCoro カフェ コロコロ)
# 6  4e33c209227111ae76921a65                             J-Ping Café
# 7  524a8385498ebdced716f505                                這裡有猫cafe
# 8  4bad7f67f964a520a6563be3                              Cafe Terry
# 9  4bce9248c564ef3b0d8eeef0                         呼嚕咖啡 Forro Cafe
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1615250682    False
# 4  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...  v-1615250682    False
# 5  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
# 6  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1615250682    False
# 7  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
# 8  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
# 9  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1615250682    False
#
#    location.lat  location.lng  \
# 0     24.150993    120.647525
# 1     24.155191    120.656951
# 2     24.150893    120.647523
# 3     24.159010    120.657284
# 4     24.165308    120.644150
# 5     24.154793    120.659122
# 6     24.159969    120.647771
# 7     24.145029    120.656488
# 8     24.151554    120.648708
# 9     24.155802    120.658250
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 24.150993, 'lng':...                 23
# 1  [{'label': 'display', 'lat': 24.155191, 'lng':...               1049
# 2  [{'label': 'display', 'lat': 24.15089250758993...                 22
# 3  [{'label': 'display', 'lat': 24.15901017468147...               1323
# 4  [{'label': 'display', 'lat': 24.165308, 'lng':...               1643
# 5  [{'label': 'display', 'lat': 24.154793, 'lng':...               1233
# 6  [{'label': 'display', 'lat': 24.15996856950740...               1007
# 7  [{'label': 'display', 'lat': 24.14502860622578...               1103
# 8  [{'label': 'display', 'lat': 24.15155397406966...                121
# 9  [{'label': 'display', 'lat': 24.155802, 'lng':...               1197
#
#   location.cc location.country                   location.formattedAddress  \
# 0          TW               臺灣                                        [臺灣]
# 1          TW               臺灣                  [西區精誠六街15號, 臺中市,  403, 臺灣]
# 2          TW               臺灣                        [公益路二段172號, 臺中市, 臺灣]
# 3          TW               臺灣                  [台灣大道二段666號, 西屯,  407, 臺灣]
# 4          TW               臺灣                 [台灣大道301號11樓, 西屯,  407, 臺灣]
# 5          TW               臺灣                   [華美西街一段81號, 西區,  403, 臺灣]
# 6          TW               臺灣                       [文心路二段213號2樓, 西屯, 臺灣]
# 7          TW               臺灣                                        [臺灣]
# 8          TW               臺灣  [418 Daying St. (DaDunShi), 南屯區,  403, 臺灣]
# 9          TW               臺灣                           [精誠三街47號, 西區, 臺灣]
#
#   location.address location.postalCode location.city location.crossStreet  \
# 0              NaN                 NaN           NaN                  NaN
# 1        西區精誠六街15號                 403           臺中市                  NaN
# 2        公益路二段172號                 NaN           臺中市                  NaN
# 3       台灣大道二段666號                 407            西屯                  NaN
# 4      台灣大道301號11樓                 407            西屯                  NaN
# 5        華美西街一段81號                 403            西區                  NaN
# 6      文心路二段213號2樓                 NaN            西屯                  NaN
# 7              NaN                 NaN           NaN                  NaN
# 8   418 Daying St.                 403           南屯區             DaDunShi
# 9          精誠三街47號                 NaN            西區                  NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
